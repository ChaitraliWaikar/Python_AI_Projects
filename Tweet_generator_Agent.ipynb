# %%
import nbformat
import os

# Path to the current notebook
# The FileNotFoundError indicates that '/content/Tweet_generator_Agent.ipynb' does not exist.
# Please ensure the filename and path are correct.
# You can check the current directory contents using !ls -F in a new code cell.
# If your notebook has a different name, please update the 'file' variable below.

# IMPORTANT: Please replace "YOUR_NOTEBOOK_NAME.ipynb" with the actual name of your notebook
# (e.g., from the output of the !ls -F command).
file = "/content/YOUR_NOTEBOOK_NAME.ipynb"  # <--- Please verify this path and filename!

# Check if the file exists before attempting to read it
if not os.path.exists(file):
    print(f"Error: The notebook file '{file}' was not found.")
    print("Please update the 'file' variable to the correct path and filename of your notebook.")
else:
    nb = nbformat.read(file, as_version=4)

    # Remove all widget metadata safely
    if "widgets" in nb.get("metadata", {}):
        del nb["metadata"]["widgets"]

    # Also clean cell-level widget metadata (optional but safest)
    for cell in nb.cells:
        if "metadata" in cell and "widgets" in cell["metadata"]:
            del cell["metadata"]["widgets"]

    # Save cleaned notebook
    nbformat.write(nb, file)

    print("✔ Notebook cleaned successfully! Upload this version to GitHub.")
# Out:
# Error: The notebook file '/content/YOUR_NOTEBOOK_NAME.ipynb' was not found.
# Please update the 'file' variable to the correct path and filename of your notebook.

# %%
# !ls -F
# Out:
# sample_data/

# %% [markdown]
# 1. Install required packages.

# %%
# !pip install google-generativeai --quite
# !pip install ipywidgets --quite.  #create a beautiful UI
# Out:
# Usage:
#   pip3 install [options] <requirement specifier> [package-index-options] ...
#   pip3 install [options] -r <requirements file> [package-index-options] ...
#   pip3 install [options] [-e] <vcs project url> ...
#   pip3 install [options] [-e] <local project path> ...
#   pip3 install [options] <archive url/path> ...
#
# no such option: --quite
#
# Usage:
#   pip3 install [options] <requirement specifier> [package-index-options] ...
#   pip3 install [options] -r <requirements file> [package-index-options] ...
#   pip3 install [options] [-e] <vcs project url> ...
#   pip3 install [options] [-e] <local project path> ...
#   pip3 install [options] <archive url/path> ...
#
# no such option: --quite.

# %% [markdown]
# 2. Import libraries

# %%
import google.generativeai as genai
import ipywidgets as widgets
from IPython.display import display, Markdown, clear_output

# %% [markdown]
# 3. Set up Gemini API

# %%
API_KEY = "AIzaSyCtvy2uyd-X7-r-HGrlI9dEvy8nqKxEnEI"
genai.configure(api_key= API_KEY)                       #config api
model = genai.GenerativeModel("gemini-2.5-flash")       #select model

# %% [markdown]
# 4. Define input form.

# %%
topic_input = widgets.Text(
    description = "Topic",
    layout = widgets.Layout(width = '400px')
    )

tone_input = widgets.Dropdown(
    description = "Tone",
    options = ['Professional', 'Casual', 'Motivational', 'Informative'],
    layout = widgets.Layout(width = '400px')
)

audience_input = widgets.Text(
    description = "Audience",
    layout = widgets.Layout(width = '400px')
)

hashtag_input = widgets.Text(
    description = "Hashtags",
    layout = widgets.Layout(width = '400px')
)

submit_button = widgets.Button(
    description = "Generate tweet",
    button_style = 'Success',
    tooltip = 'click to generate tweet',
    layout = widgets.Layout(width = '400px')
)

output = widgets.Output()

# %% [markdown]
# 5. Generate Tweet Function.

# %%
def generate_tweet(b):
  clear_output()
  prompt = f"""
  You are an expert Content Writer
  generate a tweet about the topic {topic_input.value}.
  Use a tone {tone_input.value}.
  Generate tweet for audience {audience_input.value}.
  Include the hashtags {hashtag_input.value}.
  Keep it under 280 characters.
  """
  with output:
    try:
      response = model.generate_content(prompt)
      tweet = response.text.strip()
      display(Markdown(f"### Generated tweet : \n  {tweet}"))

    except Exception as e:
      print("Error", e)

submit_button.on_click(generate_tweet)

# %% [markdown]
# 6. Display the form.

# %%
form = widgets.VBox([
    widgets.HTML(value="<h3> Tweet Generator Agent </h3>"),
    topic_input,
    tone_input,
    audience_input,
    hashtag_input,
    submit_button,
    output
])

display(form)
